# %%
from brave import Brave

brave = Brave()

query = "cobalt mining"
goggle_url = "https://raw.githubusercontent.com/CSamuelAnderson/Brave-goggles/main/academic-and-archival.goggle"
num_results = 10
result_filter = "web" # must be comma separated string

results = brave.search(q=query, goggles_id=goggle_url, count=num_results, result_filter=result_filter)

results.download_all_pdfs(path="downloads")

# %%
from brave import AsyncBrave

brave = AsyncBrave()

query = "cobalt mining"
goggle_url = "https://raw.githubusercontent.com/CSamuelAnderson/Brave-goggles/main/academic-and-archival.goggle"
num_results = 10
result_filter = "web" # must be comma separated string

results = await brave.search(q=query, goggles_id=goggle_url, count=num_results, result_filter=result_filter)

results.download_all_pdfs(path="downloads")

# %%
print(output)
# Out:
# {
#     "query": {
#         "original": "cobalt mining",
#         "show_strict_warning": false,
#         "is_navigational": false,
#         "is_news_breaking": false,
#         "spellcheck_off": true,
#         "country": "us",
#         "bad_results": false,
#         "should_fallback": false,
#         "postal_code": "",
#         "city": "",
#         "header_country": "",
#         "more_results_available": true,
#         "state": ""
#     },
#     "mixed": {
#         "type": "mixed",
#         "main": [
#             {
#                 "type": "web",
#                 "index": 0,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 1,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 2,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 3,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 4,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 5,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 6,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 7,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 8,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 9,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 10,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 11,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 12,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 13,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 14,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 15,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 16,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 17,
#                 "all": false
#             }
#         ],
#         "top": [],
#         "side": []
#     },
#     "type": "search",
#     "web": {
#         "type": "search",
#         "results": [
#             {
#                 "title": "Category:Cobalt mining - Wikipedia",
#                 "url": "https://en.wikipedia.org/wiki/Category:Cobalt_mining",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "This category has the following 2 subcategories, out of 2 total. ... The following 2 pages are in this category, out of 2 total. This list may not reflect recent changes.",
#                 "page_age": null,
#                 "profile": {
#                     "name": "Wikipedia",
#                     "url": "https://en.wikipedia.org/wiki/Category:Cobalt_mining",
#                     "long_name": "en.wikipedia.org",
#                     "img": "https://imgs.search.brave.com/0kxnVOiqv-faZvOJc7zpym4Zin1CTs1f1svfNZSzmfU/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw"
#                 },
#                 "language": "en",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "en.wikipedia.org",
#                     "hostname": "en.wikipedia.org",
#                     "favicon": "https://imgs.search.brave.com/0kxnVOiqv-faZvOJc7zpym4Zin1CTs1f1svfNZSzmfU/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw",
#                     "path": "› wiki  › Category:Cobalt_mining"
#                 },
#                 "thumbnail": null,
#                 "age": null,
#                 "content_type": null
#             },
#             {
#                 "title": "For Your Phone and EV, a Cobalt Supply Chain to a Hell on Earth ...",
#                 "url": "https://e360.yale.edu/features/siddharth-kara-cobalt-mining-labor-congo",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "The race for high-tech metals has sparked a <strong>cobalt</strong> boom in the Democratic Republic of the Congo that has come at a steep human cost. In an e360 interview, author Siddharth Kara talks about the horrific conditions in the <strong>mines</strong> that are putting thousands of workers at risk.",
#                 "page_age": "2023-04-04T04:05:01",
#                 "profile": {
#                     "name": "Yale",
#                     "url": "https://e360.yale.edu/features/siddharth-kara-cobalt-mining-labor-congo",
#                     "long_name": "e360.yale.edu",
#                     "img": "https://imgs.search.brave.com/AUDERuvde4YjeXzJqklnYgmLEiRwl92orJxgeQAroSg/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvZGNiYTVkZGYx/MWZmZTkyOTEyNzJi/M2NhYjcyYjY2NTQy/MGM0ZjhiYjU2NDNk/MWM4ODUxMTFjNmVi/NjZmMjQyNi9lMzYw/LnlhbGUuZWR1Lw"
#                 },
#                 "language": "en",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "e360.yale.edu",
#                     "hostname": "e360.yale.edu",
#                     "favicon": "https://imgs.search.brave.com/AUDERuvde4YjeXzJqklnYgmLEiRwl92orJxgeQAroSg/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvZGNiYTVkZGYx/MWZmZTkyOTEyNzJi/M2NhYjcyYjY2NTQy/MGM0ZjhiYjU2NDNk/MWM4ODUxMTFjNmVi/NjZmMjQyNi9lMzYw/LnlhbGUuZWR1Lw",
#                     "path": "› features  › siddharth-kara-cobalt-mining-labor-congo"
#                 },
#                 "thumbnail": {
#                     "src": "https://imgs.search.brave.com/MqHl9b5eA71JrGGy7RDlP-smSHjmneSkTplw9pho_So/rs:fit:200:200:1/g:ce/aHR0cHM6Ly9lMzYw/LnlhbGUuZWR1L2Fz/c2V0cy9zaXRlL0Nv/bmdvLTFfR2V0dHkt/U21hbGwuanBn",
#                     "original": "https://e360.yale.edu/assets/site/Congo-1_Getty-Small.jpg",
#                     "logo": false
#                 },
#                 "age": "April 4, 2023",
#                 "content_type": null
#             },
#             {
#                 "title": "The dangers of cobalt mining in the Congo | News | Harvard T.H. ...",
#                 "url": "https://www.hsph.harvard.edu/news/hsph-in-the-news/the-dangers-of-cobalt-mining-in-the-congo/",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "<strong>Cobalt</strong> <strong>mining</strong> is taking a huge toll on the people and environment of the Democratic Republic of the Congo (D.R.C.), according to Harvard Chan School’s Siddharth Kara.",
#                 "page_age": "2023-02-16T21:15:03",
#                 "profile": {
#                     "name": "Harvard",
#                     "url": "https://www.hsph.harvard.edu/news/hsph-in-the-news/the-dangers-of-cobalt-mining-in-the-congo/",
#                     "long_name": "hsph.harvard.edu",
#                     "img": "https://imgs.search.brave.com/0JbMNALFDBOnXaKQoZVF82NIQR0TkbSUQcwwuUkOumA/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNTk5ZGJiZDQx/MWI3MjU1N2U3OGRk/N2ZjNmRmNzljY2U4/ZGIyOTYwM2NkMWI2/NDk0ZTRmNDRlYmY4/ODkzMzg0NC93d3cu/aHNwaC5oYXJ2YXJk/LmVkdS8"
#                 },
#                 "language": "en",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "hsph.harvard.edu",
#                     "hostname": "www.hsph.harvard.edu",
#                     "favicon": "https://imgs.search.brave.com/0JbMNALFDBOnXaKQoZVF82NIQR0TkbSUQcwwuUkOumA/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNTk5ZGJiZDQx/MWI3MjU1N2U3OGRk/N2ZjNmRmNzljY2U4/ZGIyOTYwM2NkMWI2/NDk0ZTRmNDRlYmY4/ODkzMzg0NC93d3cu/aHNwaC5oYXJ2YXJk/LmVkdS8",
#                     "path": "› news  › hsph-in-the-news  › the-dangers-of-cobalt-mining-in-the-congo"
#                 },
#                 "thumbnail": {
#                     "src": "https://imgs.search.brave.com/tqEvVxJ797ID0CUORUgtZmGZWByk-qxu7UMugm01LJE/rs:fit:200:200:1/g:ce/aHR0cHM6Ly93d3cu/aHNwaC5oYXJ2YXJk/LmVkdS9uZXdzL3dw/LWNvbnRlbnQvdXBs/b2Fkcy9zaXRlcy8y/MS8yMDIwLzA3L25w/ci1mZWF0dXJlLmpw/Zw",
#                     "original": "https://www.hsph.harvard.edu/news/wp-content/uploads/sites/21/2020/07/npr-feature.jpg",
#                     "logo": false
#                 },
#                 "age": "February 16, 2023",
#                 "content_type": null
#             },
#             {
#                 "title": "Cobalt mining in the EU",
#                 "url": "https://hcss.nl/wp-content/uploads/2022/09/Cobalt-mining-in-the-EU-Securing-supplies-and-ensuring-energy-justice-PDF.pdf",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "HCSS transforms global security challenges into actionable solutions for both private and public clients. Learn more &gt;&gt;&gt;",
#                 "page_age": "2022-10-03T00:00:00",
#                 "profile": {
#                     "name": "Hcss",
#                     "url": "https://hcss.nl/wp-content/uploads/2022/09/Cobalt-mining-in-the-EU-Securing-supplies-and-ensuring-energy-justice-PDF.pdf",
#                     "long_name": "hcss.nl",
#                     "img": "https://imgs.search.brave.com/BtnTddrelKWvd2BFyZpSvL044PADCVEzDRwW1Kqszd8/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYjkzNjk4NjQx/OGE2ZGNlNWE3ZWQy/Y2ZkZjdiYTYxMzFl/OTdjOGEwMjdkMzg0/Yjg5ZmYzNjFhYTJl/OWY1OWU2Yy9oY3Nz/Lm5sLw"
#                 },
#                 "language": "unk",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "hcss.nl",
#                     "hostname": "hcss.nl",
#                     "favicon": "https://imgs.search.brave.com/BtnTddrelKWvd2BFyZpSvL044PADCVEzDRwW1Kqszd8/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYjkzNjk4NjQx/OGE2ZGNlNWE3ZWQy/Y2ZkZjdiYTYxMzFl/OTdjOGEwMjdkMzg0/Yjg5ZmYzNjFhYTJl/OWY1OWU2Yy9oY3Nz/Lm5sLw",
#                     "path": "› wp-content  › uploads  › 2022  › 09  › Cobalt-mining-in-the-EU-Securing-supplies-and-ensuring-energy-justice-PDF.pdf"
#                 },
#                 "thumbnail": null,
#                 "age": "October 3, 2022",
#                 "content_type": "pdf"
#             },
#             {
#                 "title": "Category:Cobalt mining companies - Wikipedia",
#                 "url": "https://en.wikipedia.org/wiki/Category:Cobalt_mining_companies",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "The following 9 pages are in this category, out of 9 total. This list may not reflect recent changes.",
#                 "page_age": null,
#                 "profile": {
#                     "name": "Wikipedia",
#                     "url": "https://en.wikipedia.org/wiki/Category:Cobalt_mining_companies",
#                     "long_name": "en.wikipedia.org",
#                     "img": "https://imgs.search.brave.com/0kxnVOiqv-faZvOJc7zpym4Zin1CTs1f1svfNZSzmfU/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw"
#                 },
#                 "language": "en",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "en.wikipedia.org",
#                     "hostname": "en.wikipedia.org",
#                     "favicon": "https://imgs.search.brave.com/0kxnVOiqv-faZvOJc7zpym4Zin1CTs1f1svfNZSzmfU/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw",
#                     "path": "› wiki  › Category:Cobalt_mining_companies"
#                 },
#                 "thumbnail": null,
#                 "age": null,
#                 "content_type": null
#             },
#             {
#                 "title": "Cobalt Data Sheet - Mineral Commodity Summaries 2020",
#                 "url": "https://pubs.usgs.gov/periodicals/mcs2020/mcs2020-cobalt.pdf",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "USGS Online Publications Directory · Accessibility FOIA Privacy Policies and Notices",
#                 "page_age": "2022-02-08T00:00:00",
#                 "profile": {
#                     "name": "Usgs",
#                     "url": "https://pubs.usgs.gov/periodicals/mcs2020/mcs2020-cobalt.pdf",
#                     "long_name": "pubs.usgs.gov",
#                     "img": "https://imgs.search.brave.com/i8w1U44z-G9UFlpWKK5uPP2wa1PpbmRDw9fQQ_5nC78/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYWU0Y2ZjNmMy/NmIyNWIwMzk0Mzk4/ZjNhYjBjNWYyYzE0/OWYxOGYxYTg2YTIw/ZTM5ZWQxNGMzNDE1/ZjBhYTI4OC9wdWJz/LnVzZ3MuZ292Lw"
#                 },
#                 "language": "unk",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "pubs.usgs.gov",
#                     "hostname": "pubs.usgs.gov",
#                     "favicon": "https://imgs.search.brave.com/i8w1U44z-G9UFlpWKK5uPP2wa1PpbmRDw9fQQ_5nC78/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYWU0Y2ZjNmMy/NmIyNWIwMzk0Mzk4/ZjNhYjBjNWYyYzE0/OWYxOGYxYTg2YTIw/ZTM5ZWQxNGMzNDE1/ZjBhYTI4OC9wdWJz/LnVzZ3MuZ292Lw",
#                     "path": "› periodicals  › mcs2020  › mcs2020-cobalt.pdf"
#                 },
#                 "thumbnail": null,
#                 "age": "February 8, 2022",
#                 "content_type": "pdf"
#             },
#             {
#                 "title": "Statement on Human Rights and Artisanal Cobalt Mining in",
#                 "url": "https://www.vodafone.com/content/dam/vodcom/sustainability/pdfs/Vodafone_Statement_on_Cobalt_Sourcing_2017.pdf",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "Vodafone is a leading technology communications company in Europe and Africa, keeping society connected and building a digital future. Find out more!",
#                 "page_age": null,
#                 "profile": {
#                     "name": "Vodafone",
#                     "url": "https://www.vodafone.com/content/dam/vodcom/sustainability/pdfs/Vodafone_Statement_on_Cobalt_Sourcing_2017.pdf",
#                     "long_name": "vodafone.com",
#                     "img": "https://imgs.search.brave.com/JjwiCYT9sT0GetVYNSfpZkN1ecDE0iGSBn7KENE2S3I/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYTU3YWZmYmEy/ZmZlMmY0YTFhN2Nk/YWZkNGY5NGQxMjhj/OGM2MmRlMTUxYWUz/NjI3YjU1MjRlYTc0/NzBhNTNmNy93d3cu/dm9kYWZvbmUuY29t/Lw"
#                 },
#                 "language": "unk",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "vodafone.com",
#                     "hostname": "www.vodafone.com",
#                     "favicon": "https://imgs.search.brave.com/JjwiCYT9sT0GetVYNSfpZkN1ecDE0iGSBn7KENE2S3I/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYTU3YWZmYmEy/ZmZlMmY0YTFhN2Nk/YWZkNGY5NGQxMjhj/OGM2MmRlMTUxYWUz/NjI3YjU1MjRlYTc0/NzBhNTNmNy93d3cu/dm9kYWZvbmUuY29t/Lw",
#                     "path": "› content  › dam  › vodcom  › sustainability  › pdfs  › Vodafone_Statement_on_Cobalt_Sourcing_2017.pdf"
#                 },
#                 "thumbnail": null,
#                 "age": null,
#                 "content_type": "pdf"
#             },
#             {
#                 "title": "mining cobalt-rich ferromanganese crusts and polymetallic ...",
#                 "url": "https://www.isa.org.jm/wp-content/uploads/2022/08/2006sulpcrusts-web_0.pdf",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "ISA&#x27;s contribution to the UN Decade of Ocean Science [vc_single_image image=&quot;715&quot;",
#                 "page_age": null,
#                 "profile": {
#                     "name": "Isa",
#                     "url": "https://www.isa.org.jm/wp-content/uploads/2022/08/2006sulpcrusts-web_0.pdf",
#                     "long_name": "isa.org.jm",
#                     "img": "https://imgs.search.brave.com/vI5TAGf-lvJ3bRBt2RhnYUnI-bbDmZCvN60LeOrxVLc/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMjg3NzYzMDdj/ZDk4ODA2ZTcxYTQ3/NWFmY2M3YTE5NTc3/NzhmZTAyYzQ3NmQz/ZTAxMzdlNDQ1NDgy/NzA3MjYzMi93d3cu/aXNhLm9yZy5qbS8"
#                 },
#                 "language": "unk",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "isa.org.jm",
#                     "hostname": "www.isa.org.jm",
#                     "favicon": "https://imgs.search.brave.com/vI5TAGf-lvJ3bRBt2RhnYUnI-bbDmZCvN60LeOrxVLc/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMjg3NzYzMDdj/ZDk4ODA2ZTcxYTQ3/NWFmY2M3YTE5NTc3/NzhmZTAyYzQ3NmQz/ZTAxMzdlNDQ1NDgy/NzA3MjYzMi93d3cu/aXNhLm9yZy5qbS8",
#                     "path": "› wp-content  › uploads  › 2022  › 08  › 2006sulpcrusts-web_0.pdf"
#                 },
#                 "thumbnail": null,
#                 "age": null,
#                 "content_type": "pdf"
#             },
#             {
#                 "title": "Idaho cobalt mine - Wikipedia",
#                 "url": "https://en.wikipedia.org/wiki/Idaho_cobalt_mine",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "Idaho <strong>Cobalt</strong> Operations (ICO) is a <strong>cobalt</strong> <strong>mine</strong> located in Lemhi County, Idaho in the United States near the town of Salmon. The <strong>mine</strong> has reserves amounting to 3.8 million tonnes of ore grading 0.5% <strong>cobalt</strong>. <strong>The</strong> <strong>mine</strong> will also produce copper and gold. The project is located directly adjacent ...",
#                 "page_age": "2023-03-30T21:08:07",
#                 "profile": {
#                     "name": "Wikipedia",
#                     "url": "https://en.wikipedia.org/wiki/Idaho_cobalt_mine",
#                     "long_name": "en.wikipedia.org",
#                     "img": "https://imgs.search.brave.com/0kxnVOiqv-faZvOJc7zpym4Zin1CTs1f1svfNZSzmfU/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw"
#                 },
#                 "language": "en",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "en.wikipedia.org",
#                     "hostname": "en.wikipedia.org",
#                     "favicon": "https://imgs.search.brave.com/0kxnVOiqv-faZvOJc7zpym4Zin1CTs1f1svfNZSzmfU/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw",
#                     "path": "› wiki  › Idaho_cobalt_mine"
#                 },
#                 "thumbnail": null,
#                 "age": "March 30, 2023",
#                 "content_type": null
#             },
#             {
#                 "title": "Author and anti-slavery activist to speak on cobalt mining in the ...",
#                 "url": "https://news.cornell.edu/stories/2023/11/author-and-anti-slavery-activist-speak-cobalt-mining-congo",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "Siddharth Kara, award-winning author and anti-slavery activist, will discuss the immense toll <strong>cobalt</strong> <strong>mining</strong> has had on the people and environment of the Democratic Republic of the Congo at noon on Friday, November 10.",
#                 "page_age": null,
#                 "profile": {
#                     "name": "Cornell",
#                     "url": "https://news.cornell.edu/stories/2023/11/author-and-anti-slavery-activist-speak-cobalt-mining-congo",
#                     "long_name": "news.cornell.edu",
#                     "img": "https://imgs.search.brave.com/w9wAbyDSgJnZV_xO33EdCVJShesxH146ptavho1uPQ4/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMGVhZjIyMmJh/MmNlOWYyZTY4MmNl/NzI5ZDliMGFlNjg1/NWI1YjViZTlhMjE1/ZWYwNzA3MDFjZGM2/NDExZmM5MS9uZXdz/LmNvcm5lbGwuZWR1/Lw"
#                 },
#                 "language": "en",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "news.cornell.edu",
#                     "hostname": "news.cornell.edu",
#                     "favicon": "https://imgs.search.brave.com/w9wAbyDSgJnZV_xO33EdCVJShesxH146ptavho1uPQ4/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMGVhZjIyMmJh/MmNlOWYyZTY4MmNl/NzI5ZDliMGFlNjg1/NWI1YjViZTlhMjE1/ZWYwNzA3MDFjZGM2/NDExZmM5MS9uZXdz/LmNvcm5lbGwuZWR1/Lw",
#                     "path": "› stories  › 2023  › 11  › author-and-anti-slavery-activist-speak-cobalt-mining-congo"
#                 },
#                 "thumbnail": {
#                     "src": "https://imgs.search.brave.com/0MiQLUSQLAEl67RqIBUAJMhEchHPwJk7x_I0jEAVkV0/rs:fit:200:200:1/g:ce/aHR0cHM6Ly9uZXdz/LmNvcm5lbGwuZWR1/L3NpdGVzL2RlZmF1/bHQvZmlsZXMvc3R5/bGVzL3N0b3J5X3Ro/dW1ibmFpbF9sZy9w/dWJsaWMvMl8xLnBu/Zz9pdG9rPTU0TUlP/ZjZq",
#                     "original": "https://news.cornell.edu/sites/default/files/styles/story_thumbnail_lg/public/2_1.png?itok=54MIOf6j",
#                     "logo": false
#                 },
#                 "age": null,
#                 "content_type": null
#             }
#         ],
#         "family_friendly": true
#     }
# }

# %%
from pprint import pprint
pprint(output)
# Out:
# {'mixed': {'main': [{'all': False, 'index': 0, 'type': 'web'},
#                     {'all': False, 'index': 1, 'type': 'web'},
#                     {'all': False, 'index': 2, 'type': 'web'},
#                     {'all': False, 'index': 3, 'type': 'web'},
#                     {'all': False, 'index': 4, 'type': 'web'},
#                     {'all': False, 'index': 5, 'type': 'web'},
#                     {'all': False, 'index': 6, 'type': 'web'},
#                     {'all': False, 'index': 7, 'type': 'web'},
#                     {'all': False, 'index': 8, 'type': 'web'},
#                     {'all': False, 'index': 9, 'type': 'web'},
#                     {'all': False, 'index': 10, 'type': 'web'},
#                     {'all': False, 'index': 11, 'type': 'web'},
#                     {'all': False, 'index': 12, 'type': 'web'},
#                     {'all': False, 'index': 13, 'type': 'web'},
#                     {'all': False, 'index': 14, 'type': 'web'},
#                     {'all': False, 'index': 15, 'type': 'web'},
#                     {'all': False, 'index': 16, 'type': 'web'},
#                     {'all': False, 'index': 17, 'type': 'web'}],
#            'side': [],
#            'top': [],
#            'type': 'mixed'},
#  'query': {'bad_results': False,
#            'city': '',
#            'country': 'us',
#            'header_country': '',
#            'is_navigational': False,
#            'is_news_breaking': False,
#            'more_results_available': True,
#            'original': 'cobalt mining',
#            'postal_code': '',
#            'should_fallback': False,
#            'show_strict_warning': False,
#            'spellcheck_off': True,
#            'state': ''},
#  'type': 'search',
#  'web': {'family_friendly': True,
#          'results': [{'description': 'This category has the following 2 '
#                                      'subcategories, out of 2 total. ... The '
#                                      'following 2 pages are in this category, '
#                                      'out of 2 total. This list may not '
#                                      'reflect recent changes.',
#                       'family_friendly': True,
#                       'is_source_both': False,
#                       'is_source_local': False,
#                       'language': 'en',
#                       'meta_url': {'favicon': 'https://imgs.search.brave.com/0kxnVOiqv-faZvOJc7zpym4Zin1CTs1f1svfNZSzmfU/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw',
#                                    'hostname': 'en.wikipedia.org',
#                                    'netloc': 'en.wikipedia.org',
#                                    'path': '› wiki  › Category:Cobalt_mining',
#                                    'scheme': 'https'},
#                       'profile': {'img': 'https://imgs.search.brave.com/0kxnVOiqv-faZvOJc7zpym4Zin1CTs1f1svfNZSzmfU/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw',
#                                   'long_name': 'en.wikipedia.org',
#                                   'name': 'Wikipedia',
#                                   'url': 'https://en.wikipedia.org/wiki/Category:Cobalt_mining'},
#                       'subtype': 'generic',
#                       'title': 'Category:Cobalt mining - Wikipedia',
#                       'type': 'search_result',
#                       'url': 'https://en.wikipedia.org/wiki/Category:Cobalt_mining'},
#                      {'age': 'April 4, 2023',
#                       'description': 'The race for high-tech metals has '
#                                      'sparked a <strong>cobalt</strong> boom '
#                                      'in the Democratic Republic of the Congo '
#                                      'that has come at a steep human cost. In '
#                                      'an e360 interview, author Siddharth Kara '
#                                      'talks about the horrific conditions in '
#                                      'the <strong>mines</strong> that are '
#                                      'putting thousands of workers at risk.',
#                       'family_friendly': True,
#                       'is_source_both': False,
#                       'is_source_local': False,
#                       'language': 'en',
#                       'meta_url': {'favicon': 'https://imgs.search.brave.com/AUDERuvde4YjeXzJqklnYgmLEiRwl92orJxgeQAroSg/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvZGNiYTVkZGYx/MWZmZTkyOTEyNzJi/M2NhYjcyYjY2NTQy/MGM0ZjhiYjU2NDNk/MWM4ODUxMTFjNmVi/NjZmMjQyNi9lMzYw/LnlhbGUuZWR1Lw',
#                                    'hostname': 'e360.yale.edu',
#                                    'netloc': 'e360.yale.edu',
#                                    'path': '› features  › '
#                                            'siddharth-kara-cobalt-mining-labor-congo',
#                                    'scheme': 'https'},
#                       'page_age': '2023-04-04T04:05:01',
#                       'profile': {'img': 'https://imgs.search.brave.com/AUDERuvde4YjeXzJqklnYgmLEiRwl92orJxgeQAroSg/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvZGNiYTVkZGYx/MWZmZTkyOTEyNzJi/M2NhYjcyYjY2NTQy/MGM0ZjhiYjU2NDNk/MWM4ODUxMTFjNmVi/NjZmMjQyNi9lMzYw/LnlhbGUuZWR1Lw',
#                                   'long_name': 'e360.yale.edu',
#                                   'name': 'Yale',
#                                   'url': 'https://e360.yale.edu/features/siddharth-kara-cobalt-mining-labor-congo'},
#                       'subtype': 'generic',
#                       'thumbnail': {'logo': False,
#                                     'original': 'https://e360.yale.edu/assets/site/Congo-1_Getty-Small.jpg',
#                                     'src': 'https://imgs.search.brave.com/MqHl9b5eA71JrGGy7RDlP-smSHjmneSkTplw9pho_So/rs:fit:200:200:1/g:ce/aHR0cHM6Ly9lMzYw/LnlhbGUuZWR1L2Fz/c2V0cy9zaXRlL0Nv/bmdvLTFfR2V0dHkt/U21hbGwuanBn'},
#                       'title': 'For Your Phone and EV, a Cobalt Supply Chain '
#                                'to a Hell on Earth ...',
#                       'type': 'search_result',
#                       'url': 'https://e360.yale.edu/features/siddharth-kara-cobalt-mining-labor-congo'},
#                      {'age': 'February 16, 2023',
#                       'description': '<strong>Cobalt</strong> '
#                                      '<strong>mining</strong> is taking a huge '
#                                      'toll on the people and environment of '
#                                      'the Democratic Republic of the Congo '
#                                      '(D.R.C.), according to Harvard Chan '
#                                      'School’s Siddharth Kara.',
#                       'family_friendly': True,
#                       'is_source_both': False,
#                       'is_source_local': False,
#                       'language': 'en',
#                       'meta_url': {'favicon': 'https://imgs.search.brave.com/0JbMNALFDBOnXaKQoZVF82NIQR0TkbSUQcwwuUkOumA/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNTk5ZGJiZDQx/MWI3MjU1N2U3OGRk/N2ZjNmRmNzljY2U4/ZGIyOTYwM2NkMWI2/NDk0ZTRmNDRlYmY4/ODkzMzg0NC93d3cu/aHNwaC5oYXJ2YXJk/LmVkdS8',
#                                    'hostname': 'www.hsph.harvard.edu',
#                                    'netloc': 'hsph.harvard.edu',
#                                    'path': '› news  › hsph-in-the-news  › '
#                                            'the-dangers-of-cobalt-mining-in-the-congo',
#                                    'scheme': 'https'},
#                       'page_age': '2023-02-16T21:15:03',
#                       'profile': {'img': 'https://imgs.search.brave.com/0JbMNALFDBOnXaKQoZVF82NIQR0TkbSUQcwwuUkOumA/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNTk5ZGJiZDQx/MWI3MjU1N2U3OGRk/N2ZjNmRmNzljY2U4/ZGIyOTYwM2NkMWI2/NDk0ZTRmNDRlYmY4/ODkzMzg0NC93d3cu/aHNwaC5oYXJ2YXJk/LmVkdS8',
#                                   'long_name': 'hsph.harvard.edu',
#                                   'name': 'Harvard',
#                                   'url': 'https://www.hsph.harvard.edu/news/hsph-in-the-news/the-dangers-of-cobalt-mining-in-the-congo/'},
#                       'subtype': 'generic',
#                       'thumbnail': {'logo': False,
#                                     'original': 'https://www.hsph.harvard.edu/news/wp-content/uploads/sites/21/2020/07/npr-feature.jpg',
#                                     'src': 'https://imgs.search.brave.com/tqEvVxJ797ID0CUORUgtZmGZWByk-qxu7UMugm01LJE/rs:fit:200:200:1/g:ce/aHR0cHM6Ly93d3cu/aHNwaC5oYXJ2YXJk/LmVkdS9uZXdzL3dw/LWNvbnRlbnQvdXBs/b2Fkcy9zaXRlcy8y/MS8yMDIwLzA3L25w/ci1mZWF0dXJlLmpw/Zw'},
#                       'title': 'The dangers of cobalt mining in the Congo | '
#                                'News | Harvard T.H. ...',
#                       'type': 'search_result',
#                       'url': 'https://www.hsph.harvard.edu/news/hsph-in-the-news/the-dangers-of-cobalt-mining-in-the-congo/'},
#                      {'age': 'October 3, 2022',
#                       'content_type': 'pdf',
#                       'description': 'HCSS transforms global security '
#                                      'challenges into actionable solutions for '
#                                      'both private and public clients. Learn '
#                                      'more &gt;&gt;&gt;',
#                       'family_friendly': True,
#                       'is_source_both': False,
#                       'is_source_local': False,
#                       'language': 'unk',
#                       'meta_url': {'favicon': 'https://imgs.search.brave.com/BtnTddrelKWvd2BFyZpSvL044PADCVEzDRwW1Kqszd8/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYjkzNjk4NjQx/OGE2ZGNlNWE3ZWQy/Y2ZkZjdiYTYxMzFl/OTdjOGEwMjdkMzg0/Yjg5ZmYzNjFhYTJl/OWY1OWU2Yy9oY3Nz/Lm5sLw',
#                                    'hostname': 'hcss.nl',
#                                    'netloc': 'hcss.nl',
#                                    'path': '› wp-content  › uploads  › 2022  › '
#                                            '09  › '
#                                            'Cobalt-mining-in-the-EU-Securing-supplies-and-ensuring-energy-justice-PDF.pdf',
#                                    'scheme': 'https'},
#                       'page_age': '2022-10-03T00:00:00',
#                       'profile': {'img': 'https://imgs.search.brave.com/BtnTddrelKWvd2BFyZpSvL044PADCVEzDRwW1Kqszd8/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYjkzNjk4NjQx/OGE2ZGNlNWE3ZWQy/Y2ZkZjdiYTYxMzFl/OTdjOGEwMjdkMzg0/Yjg5ZmYzNjFhYTJl/OWY1OWU2Yy9oY3Nz/Lm5sLw',
#                                   'long_name': 'hcss.nl',
#                                   'name': 'Hcss',
#                                   'url': 'https://hcss.nl/wp-content/uploads/2022/09/Cobalt-mining-in-the-EU-Securing-supplies-and-ensuring-energy-justice-PDF.pdf'},
#                       'subtype': 'generic',
#                       'title': 'Cobalt mining in the EU',
#                       'type': 'search_result',
#                       'url': 'https://hcss.nl/wp-content/uploads/2022/09/Cobalt-mining-in-the-EU-Securing-supplies-and-ensuring-energy-justice-PDF.pdf'},
#                      {'description': 'The following 9 pages are in this '
#                                      'category, out of 9 total. This list may '
#                                      'not reflect recent changes.',
#                       'family_friendly': True,
#                       'is_source_both': False,
#                       'is_source_local': False,
#                       'language': 'en',
#                       'meta_url': {'favicon': 'https://imgs.search.brave.com/0kxnVOiqv-faZvOJc7zpym4Zin1CTs1f1svfNZSzmfU/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw',
#                                    'hostname': 'en.wikipedia.org',
#                                    'netloc': 'en.wikipedia.org',
#                                    'path': '› wiki  › '
#                                            'Category:Cobalt_mining_companies',
#                                    'scheme': 'https'},
#                       'profile': {'img': 'https://imgs.search.brave.com/0kxnVOiqv-faZvOJc7zpym4Zin1CTs1f1svfNZSzmfU/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw',
#                                   'long_name': 'en.wikipedia.org',
#                                   'name': 'Wikipedia',
#                                   'url': 'https://en.wikipedia.org/wiki/Category:Cobalt_mining_companies'},
#                       'subtype': 'generic',
#                       'title': 'Category:Cobalt mining companies - Wikipedia',
#                       'type': 'search_result',
#                       'url': 'https://en.wikipedia.org/wiki/Category:Cobalt_mining_companies'},
#                      {'age': 'February 8, 2022',
#                       'content_type': 'pdf',
#                       'description': 'USGS Online Publications Directory · '
#                                      'Accessibility FOIA Privacy Policies and '
#                                      'Notices',
#                       'family_friendly': True,
#                       'is_source_both': False,
#                       'is_source_local': False,
#                       'language': 'unk',
#                       'meta_url': {'favicon': 'https://imgs.search.brave.com/i8w1U44z-G9UFlpWKK5uPP2wa1PpbmRDw9fQQ_5nC78/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYWU0Y2ZjNmMy/NmIyNWIwMzk0Mzk4/ZjNhYjBjNWYyYzE0/OWYxOGYxYTg2YTIw/ZTM5ZWQxNGMzNDE1/ZjBhYTI4OC9wdWJz/LnVzZ3MuZ292Lw',
#                                    'hostname': 'pubs.usgs.gov',
#                                    'netloc': 'pubs.usgs.gov',
#                                    'path': '› periodicals  › mcs2020  › '
#                                            'mcs2020-cobalt.pdf',
#                                    'scheme': 'https'},
#                       'page_age': '2022-02-08T00:00:00',
#                       'profile': {'img': 'https://imgs.search.brave.com/i8w1U44z-G9UFlpWKK5uPP2wa1PpbmRDw9fQQ_5nC78/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYWU0Y2ZjNmMy/NmIyNWIwMzk0Mzk4/ZjNhYjBjNWYyYzE0/OWYxOGYxYTg2YTIw/ZTM5ZWQxNGMzNDE1/ZjBhYTI4OC9wdWJz/LnVzZ3MuZ292Lw',
#                                   'long_name': 'pubs.usgs.gov',
#                                   'name': 'Usgs',
#                                   'url': 'https://pubs.usgs.gov/periodicals/mcs2020/mcs2020-cobalt.pdf'},
#                       'subtype': 'generic',
#                       'title': 'Cobalt Data Sheet - Mineral Commodity '
#                                'Summaries 2020',
#                       'type': 'search_result',
#                       'url': 'https://pubs.usgs.gov/periodicals/mcs2020/mcs2020-cobalt.pdf'},
#                      {'content_type': 'pdf',
#                       'description': 'Vodafone is a leading technology '
#                                      'communications company in Europe and '
#                                      'Africa, keeping society connected and '
#                                      'building a digital future. Find out '
#                                      'more!',
#                       'family_friendly': True,
#                       'is_source_both': False,
#                       'is_source_local': False,
#                       'language': 'unk',
#                       'meta_url': {'favicon': 'https://imgs.search.brave.com/JjwiCYT9sT0GetVYNSfpZkN1ecDE0iGSBn7KENE2S3I/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYTU3YWZmYmEy/ZmZlMmY0YTFhN2Nk/YWZkNGY5NGQxMjhj/OGM2MmRlMTUxYWUz/NjI3YjU1MjRlYTc0/NzBhNTNmNy93d3cu/dm9kYWZvbmUuY29t/Lw',
#                                    'hostname': 'www.vodafone.com',
#                                    'netloc': 'vodafone.com',
#                                    'path': '› content  › dam  › vodcom  › '
#                                            'sustainability  › pdfs  › '
#                                            'Vodafone_Statement_on_Cobalt_Sourcing_2017.pdf',
#                                    'scheme': 'https'},
#                       'profile': {'img': 'https://imgs.search.brave.com/JjwiCYT9sT0GetVYNSfpZkN1ecDE0iGSBn7KENE2S3I/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYTU3YWZmYmEy/ZmZlMmY0YTFhN2Nk/YWZkNGY5NGQxMjhj/OGM2MmRlMTUxYWUz/NjI3YjU1MjRlYTc0/NzBhNTNmNy93d3cu/dm9kYWZvbmUuY29t/Lw',
#                                   'long_name': 'vodafone.com',
#                                   'name': 'Vodafone',
#                                   'url': 'https://www.vodafone.com/content/dam/vodcom/sustainability/pdfs/Vodafone_Statement_on_Cobalt_Sourcing_2017.pdf'},
#                       'subtype': 'generic',
#                       'title': 'Statement on Human Rights and Artisanal Cobalt '
#                                'Mining in',
#                       'type': 'search_result',
#                       'url': 'https://www.vodafone.com/content/dam/vodcom/sustainability/pdfs/Vodafone_Statement_on_Cobalt_Sourcing_2017.pdf'},
#                      {'content_type': 'pdf',
#                       'description': 'ISA&#x27;s contribution to the UN Decade '
#                                      'of Ocean Science [vc_single_image '
#                                      'image=&quot;715&quot;',
#                       'family_friendly': True,
#                       'is_source_both': False,
#                       'is_source_local': False,
#                       'language': 'unk',
#                       'meta_url': {'favicon': 'https://imgs.search.brave.com/vI5TAGf-lvJ3bRBt2RhnYUnI-bbDmZCvN60LeOrxVLc/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMjg3NzYzMDdj/ZDk4ODA2ZTcxYTQ3/NWFmY2M3YTE5NTc3/NzhmZTAyYzQ3NmQz/ZTAxMzdlNDQ1NDgy/NzA3MjYzMi93d3cu/aXNhLm9yZy5qbS8',
#                                    'hostname': 'www.isa.org.jm',
#                                    'netloc': 'isa.org.jm',
#                                    'path': '› wp-content  › uploads  › 2022  › '
#                                            '08  › 2006sulpcrusts-web_0.pdf',
#                                    'scheme': 'https'},
#                       'profile': {'img': 'https://imgs.search.brave.com/vI5TAGf-lvJ3bRBt2RhnYUnI-bbDmZCvN60LeOrxVLc/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMjg3NzYzMDdj/ZDk4ODA2ZTcxYTQ3/NWFmY2M3YTE5NTc3/NzhmZTAyYzQ3NmQz/ZTAxMzdlNDQ1NDgy/NzA3MjYzMi93d3cu/aXNhLm9yZy5qbS8',
#                                   'long_name': 'isa.org.jm',
#                                   'name': 'Isa',
#                                   'url': 'https://www.isa.org.jm/wp-content/uploads/2022/08/2006sulpcrusts-web_0.pdf'},
#                       'subtype': 'generic',
#                       'title': 'mining cobalt-rich ferromanganese crusts and '
#                                'polymetallic ...',
#                       'type': 'search_result',
#                       'url': 'https://www.isa.org.jm/wp-content/uploads/2022/08/2006sulpcrusts-web_0.pdf'},
#                      {'age': 'March 30, 2023',
#                       'deep_results': {'buttons': [{'title': 'Background',
#                                                     'type': 'button_result',
#                                                     'url': 'https://en.wikipedia.org/wiki/Idaho_cobalt_mine#Background'}]},
#                       'description': 'Idaho <strong>Cobalt</strong> Operations '
#                                      '(ICO) is a <strong>cobalt</strong> '
#                                      '<strong>mine</strong> located in Lemhi '
#                                      'County, Idaho in the United States near '
#                                      'the town of Salmon. The '
#                                      '<strong>mine</strong> has reserves '
#                                      'amounting to 3.8 million tonnes of ore '
#                                      'grading 0.5% <strong>cobalt</strong>. '
#                                      '<strong>The</strong> '
#                                      '<strong>mine</strong> will also produce '
#                                      'copper and gold. The project is located '
#                                      'directly adjacent ...',
#                       'family_friendly': True,
#                       'is_source_both': False,
#                       'is_source_local': False,
#                       'language': 'en',
#                       'meta_url': {'favicon': 'https://imgs.search.brave.com/0kxnVOiqv-faZvOJc7zpym4Zin1CTs1f1svfNZSzmfU/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw',
#                                    'hostname': 'en.wikipedia.org',
#                                    'netloc': 'en.wikipedia.org',
#                                    'path': '› wiki  › Idaho_cobalt_mine',
#                                    'scheme': 'https'},
#                       'page_age': '2023-03-30T21:08:07',
#                       'profile': {'img': 'https://imgs.search.brave.com/0kxnVOiqv-faZvOJc7zpym4Zin1CTs1f1svfNZSzmfU/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw',
#                                   'long_name': 'en.wikipedia.org',
#                                   'name': 'Wikipedia',
#                                   'url': 'https://en.wikipedia.org/wiki/Idaho_cobalt_mine'},
#                       'subtype': 'generic',
#                       'title': 'Idaho cobalt mine - Wikipedia',
#                       'type': 'search_result',
#                       'url': 'https://en.wikipedia.org/wiki/Idaho_cobalt_mine'},
#                      {'description': 'Siddharth Kara, award-winning author and '
#                                      'anti-slavery activist, will discuss the '
#                                      'immense toll <strong>cobalt</strong> '
#                                      '<strong>mining</strong> has had on the '
#                                      'people and environment of the Democratic '
#                                      'Republic of the Congo at noon on Friday, '
#                                      'November 10.',
#                       'family_friendly': True,
#                       'is_source_both': False,
#                       'is_source_local': False,
#                       'language': 'en',
#                       'meta_url': {'favicon': 'https://imgs.search.brave.com/w9wAbyDSgJnZV_xO33EdCVJShesxH146ptavho1uPQ4/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMGVhZjIyMmJh/MmNlOWYyZTY4MmNl/NzI5ZDliMGFlNjg1/NWI1YjViZTlhMjE1/ZWYwNzA3MDFjZGM2/NDExZmM5MS9uZXdz/LmNvcm5lbGwuZWR1/Lw',
#                                    'hostname': 'news.cornell.edu',
#                                    'netloc': 'news.cornell.edu',
#                                    'path': '› stories  › 2023  › 11  › '
#                                            'author-and-anti-slavery-activist-speak-cobalt-mining-congo',
#                                    'scheme': 'https'},
#                       'profile': {'img': 'https://imgs.search.brave.com/w9wAbyDSgJnZV_xO33EdCVJShesxH146ptavho1uPQ4/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMGVhZjIyMmJh/MmNlOWYyZTY4MmNl/NzI5ZDliMGFlNjg1/NWI1YjViZTlhMjE1/ZWYwNzA3MDFjZGM2/NDExZmM5MS9uZXdz/LmNvcm5lbGwuZWR1/Lw',
#                                   'long_name': 'news.cornell.edu',
#                                   'name': 'Cornell',
#                                   'url': 'https://news.cornell.edu/stories/2023/11/author-and-anti-slavery-activist-speak-cobalt-mining-congo'},
#                       'subtype': 'generic',
#                       'thumbnail': {'logo': False,
#                                     'original': 'https://news.cornell.edu/sites/default/files/styles/story_thumbnail_lg/public/2_1.png?itok=54MIOf6j',
#                                     'src': 'https://imgs.search.brave.com/0MiQLUSQLAEl67RqIBUAJMhEchHPwJk7x_I0jEAVkV0/rs:fit:200:200:1/g:ce/aHR0cHM6Ly9uZXdz/LmNvcm5lbGwuZWR1/L3NpdGVzL2RlZmF1/bHQvZmlsZXMvc3R5/bGVzL3N0b3J5X3Ro/dW1ibmFpbF9sZy9w/dWJsaWMvMl8xLnBu/Zz9pdG9rPTU0TUlP/ZjZq'},
#                       'title': 'Author and anti-slavery activist to speak on '
#                                'cobalt mining in the ...',
#                       'type': 'search_result',
#                       'url': 'https://news.cornell.edu/stories/2023/11/author-and-anti-slavery-activist-speak-cobalt-mining-congo'}],
#          'type': 'search'}}

# %%
# Out:
# {
#     "query": {
#         "original": "cobalt mining",
#         "show_strict_warning": false,
#         "is_navigational": false,
#         "is_news_breaking": false,
#         "spellcheck_off": true,
#         "country": "us",
#         "bad_results": false,
#         "should_fallback": false,
#         "postal_code": "",
#         "city": "",
#         "header_country": "",
#         "more_results_available": true,
#         "state": ""
#     },
#     "mixed": {
#         "type": "mixed",
#         "main": [
#             {
#                 "type": "web",
#                 "index": 0,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 1,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 2,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 3,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 4,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 5,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 6,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 7,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 8,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 9,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 10,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 11,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 12,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 13,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 14,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 15,
#                 "all": false
#             },
#             {
#                 "type": "web",
#                 "index": 16,
#                 "all": false
#             }
#         ],
#         "top": [],
#         "side": []
#     },
#     "type": "search",
#     "web": {
#         "type": "search",
#         "results": [
#             {
#                 "title": "Category:Cobalt mining - Wikipedia",
#                 "url": "https://en.wikipedia.org/wiki/Category:Cobalt_mining",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "This category has the following 2 subcategories, out of 2 total. ... The following 2 pages are in this category, out of 2 total. This list may not reflect recent changes.",
#                 "page_age": null,
#                 "profile": {
#                     "name": "Wikipedia",
#                     "url": "https://en.wikipedia.org/wiki/Category:Cobalt_mining",
#                     "long_name": "en.wikipedia.org",
#                     "img": "https://imgs.search.brave.com/0kxnVOiqv-faZvOJc7zpym4Zin1CTs1f1svfNZSzmfU/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw"
#                 },
#                 "language": "en",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "en.wikipedia.org",
#                     "hostname": "en.wikipedia.org",
#                     "favicon": "https://imgs.search.brave.com/0kxnVOiqv-faZvOJc7zpym4Zin1CTs1f1svfNZSzmfU/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw",
#                     "path": "› wiki  › Category:Cobalt_mining"
#                 },
#                 "thumbnail": null,
#                 "age": null
#             },
#             {
#                 "title": "For Your Phone and EV, a Cobalt Supply Chain to a Hell on Earth ...",
#                 "url": "https://e360.yale.edu/features/siddharth-kara-cobalt-mining-labor-congo",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "The race for high-tech metals has sparked a <strong>cobalt</strong> boom in the Democratic Republic of the Congo that has come at a steep human cost. In an e360 interview, author Siddharth Kara talks about the horrific conditions in the <strong>mines</strong> that are putting thousands of workers at risk.",
#                 "page_age": "2023-04-04T04:05:01",
#                 "profile": {
#                     "name": "Yale",
#                     "url": "https://e360.yale.edu/features/siddharth-kara-cobalt-mining-labor-congo",
#                     "long_name": "e360.yale.edu",
#                     "img": "https://imgs.search.brave.com/AUDERuvde4YjeXzJqklnYgmLEiRwl92orJxgeQAroSg/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvZGNiYTVkZGYx/MWZmZTkyOTEyNzJi/M2NhYjcyYjY2NTQy/MGM0ZjhiYjU2NDNk/MWM4ODUxMTFjNmVi/NjZmMjQyNi9lMzYw/LnlhbGUuZWR1Lw"
#                 },
#                 "language": "en",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "e360.yale.edu",
#                     "hostname": "e360.yale.edu",
#                     "favicon": "https://imgs.search.brave.com/AUDERuvde4YjeXzJqklnYgmLEiRwl92orJxgeQAroSg/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvZGNiYTVkZGYx/MWZmZTkyOTEyNzJi/M2NhYjcyYjY2NTQy/MGM0ZjhiYjU2NDNk/MWM4ODUxMTFjNmVi/NjZmMjQyNi9lMzYw/LnlhbGUuZWR1Lw",
#                     "path": "› features  › siddharth-kara-cobalt-mining-labor-congo"
#                 },
#                 "thumbnail": {
#                     "src": "https://imgs.search.brave.com/MqHl9b5eA71JrGGy7RDlP-smSHjmneSkTplw9pho_So/rs:fit:200:200:1/g:ce/aHR0cHM6Ly9lMzYw/LnlhbGUuZWR1L2Fz/c2V0cy9zaXRlL0Nv/bmdvLTFfR2V0dHkt/U21hbGwuanBn",
#                     "original": "https://e360.yale.edu/assets/site/Congo-1_Getty-Small.jpg",
#                     "logo": false
#                 },
#                 "age": "April 4, 2023"
#             },
#             {
#                 "title": "The dangers of cobalt mining in the Congo | News | Harvard T.H. ...",
#                 "url": "https://www.hsph.harvard.edu/news/hsph-in-the-news/the-dangers-of-cobalt-mining-in-the-congo/",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "<strong>Cobalt</strong> <strong>mining</strong> is taking a huge toll on the people and environment of the Democratic Republic of the Congo (D.R.C.), according to Harvard Chan School’s Siddharth Kara.",
#                 "page_age": "2023-02-16T21:15:03",
#                 "profile": {
#                     "name": "Harvard",
#                     "url": "https://www.hsph.harvard.edu/news/hsph-in-the-news/the-dangers-of-cobalt-mining-in-the-congo/",
#                     "long_name": "hsph.harvard.edu",
#                     "img": "https://imgs.search.brave.com/0JbMNALFDBOnXaKQoZVF82NIQR0TkbSUQcwwuUkOumA/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNTk5ZGJiZDQx/MWI3MjU1N2U3OGRk/N2ZjNmRmNzljY2U4/ZGIyOTYwM2NkMWI2/NDk0ZTRmNDRlYmY4/ODkzMzg0NC93d3cu/aHNwaC5oYXJ2YXJk/LmVkdS8"
#                 },
#                 "language": "en",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "hsph.harvard.edu",
#                     "hostname": "www.hsph.harvard.edu",
#                     "favicon": "https://imgs.search.brave.com/0JbMNALFDBOnXaKQoZVF82NIQR0TkbSUQcwwuUkOumA/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNTk5ZGJiZDQx/MWI3MjU1N2U3OGRk/N2ZjNmRmNzljY2U4/ZGIyOTYwM2NkMWI2/NDk0ZTRmNDRlYmY4/ODkzMzg0NC93d3cu/aHNwaC5oYXJ2YXJk/LmVkdS8",
#                     "path": "› news  › hsph-in-the-news  › the-dangers-of-cobalt-mining-in-the-congo"
#                 },
#                 "thumbnail": {
#                     "src": "https://imgs.search.brave.com/tqEvVxJ797ID0CUORUgtZmGZWByk-qxu7UMugm01LJE/rs:fit:200:200:1/g:ce/aHR0cHM6Ly93d3cu/aHNwaC5oYXJ2YXJk/LmVkdS9uZXdzL3dw/LWNvbnRlbnQvdXBs/b2Fkcy9zaXRlcy8y/MS8yMDIwLzA3L25w/ci1mZWF0dXJlLmpw/Zw",
#                     "original": "https://www.hsph.harvard.edu/news/wp-content/uploads/sites/21/2020/07/npr-feature.jpg",
#                     "logo": false
#                 },
#                 "age": "February 16, 2023"
#             },
#             {
#                 "title": "Cobalt mining in the EU",
#                 "url": "https://hcss.nl/wp-content/uploads/2022/09/Cobalt-mining-in-the-EU-Securing-supplies-and-ensuring-energy-justice-PDF.pdf",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "HCSS transforms global security challenges into actionable solutions for both private and public clients. Learn more &gt;&gt;&gt;",
#                 "page_age": "2022-10-03T00:00:00",
#                 "profile": {
#                     "name": "Hcss",
#                     "url": "https://hcss.nl/wp-content/uploads/2022/09/Cobalt-mining-in-the-EU-Securing-supplies-and-ensuring-energy-justice-PDF.pdf",
#                     "long_name": "hcss.nl",
#                     "img": "https://imgs.search.brave.com/BtnTddrelKWvd2BFyZpSvL044PADCVEzDRwW1Kqszd8/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYjkzNjk4NjQx/OGE2ZGNlNWE3ZWQy/Y2ZkZjdiYTYxMzFl/OTdjOGEwMjdkMzg0/Yjg5ZmYzNjFhYTJl/OWY1OWU2Yy9oY3Nz/Lm5sLw"
#                 },
#                 "language": "unk",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "hcss.nl",
#                     "hostname": "hcss.nl",
#                     "favicon": "https://imgs.search.brave.com/BtnTddrelKWvd2BFyZpSvL044PADCVEzDRwW1Kqszd8/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYjkzNjk4NjQx/OGE2ZGNlNWE3ZWQy/Y2ZkZjdiYTYxMzFl/OTdjOGEwMjdkMzg0/Yjg5ZmYzNjFhYTJl/OWY1OWU2Yy9oY3Nz/Lm5sLw",
#                     "path": "› wp-content  › uploads  › 2022  › 09  › Cobalt-mining-in-the-EU-Securing-supplies-and-ensuring-energy-justice-PDF.pdf"
#                 },
#                 "thumbnail": null,
#                 "age": "October 3, 2022"
#             },
#             {
#                 "title": "Category:Cobalt mining companies - Wikipedia",
#                 "url": "https://en.wikipedia.org/wiki/Category:Cobalt_mining_companies",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "The following 9 pages are in this category, out of 9 total. This list may not reflect recent changes.",
#                 "page_age": null,
#                 "profile": {
#                     "name": "Wikipedia",
#                     "url": "https://en.wikipedia.org/wiki/Category:Cobalt_mining_companies",
#                     "long_name": "en.wikipedia.org",
#                     "img": "https://imgs.search.brave.com/0kxnVOiqv-faZvOJc7zpym4Zin1CTs1f1svfNZSzmfU/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw"
#                 },
#                 "language": "en",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "en.wikipedia.org",
#                     "hostname": "en.wikipedia.org",
#                     "favicon": "https://imgs.search.brave.com/0kxnVOiqv-faZvOJc7zpym4Zin1CTs1f1svfNZSzmfU/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw",
#                     "path": "› wiki  › Category:Cobalt_mining_companies"
#                 },
#                 "thumbnail": null,
#                 "age": null
#             },
#             {
#                 "title": "Cobalt Data Sheet - Mineral Commodity Summaries 2020",
#                 "url": "https://pubs.usgs.gov/periodicals/mcs2020/mcs2020-cobalt.pdf",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "USGS Online Publications Directory · Accessibility FOIA Privacy Policies and Notices",
#                 "page_age": "2022-02-08T00:00:00",
#                 "profile": {
#                     "name": "Usgs",
#                     "url": "https://pubs.usgs.gov/periodicals/mcs2020/mcs2020-cobalt.pdf",
#                     "long_name": "pubs.usgs.gov",
#                     "img": "https://imgs.search.brave.com/i8w1U44z-G9UFlpWKK5uPP2wa1PpbmRDw9fQQ_5nC78/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYWU0Y2ZjNmMy/NmIyNWIwMzk0Mzk4/ZjNhYjBjNWYyYzE0/OWYxOGYxYTg2YTIw/ZTM5ZWQxNGMzNDE1/ZjBhYTI4OC9wdWJz/LnVzZ3MuZ292Lw"
#                 },
#                 "language": "unk",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "pubs.usgs.gov",
#                     "hostname": "pubs.usgs.gov",
#                     "favicon": "https://imgs.search.brave.com/i8w1U44z-G9UFlpWKK5uPP2wa1PpbmRDw9fQQ_5nC78/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYWU0Y2ZjNmMy/NmIyNWIwMzk0Mzk4/ZjNhYjBjNWYyYzE0/OWYxOGYxYTg2YTIw/ZTM5ZWQxNGMzNDE1/ZjBhYTI4OC9wdWJz/LnVzZ3MuZ292Lw",
#                     "path": "› periodicals  › mcs2020  › mcs2020-cobalt.pdf"
#                 },
#                 "thumbnail": null,
#                 "age": "February 8, 2022"
#             },
#             {
#                 "title": "Statement on Human Rights and Artisanal Cobalt Mining in",
#                 "url": "https://www.vodafone.com/content/dam/vodcom/sustainability/pdfs/Vodafone_Statement_on_Cobalt_Sourcing_2017.pdf",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "Vodafone is a leading technology communications company in Europe and Africa, keeping society connected and building a digital future. Find out more!",
#                 "page_age": null,
#                 "profile": {
#                     "name": "Vodafone",
#                     "url": "https://www.vodafone.com/content/dam/vodcom/sustainability/pdfs/Vodafone_Statement_on_Cobalt_Sourcing_2017.pdf",
#                     "long_name": "vodafone.com",
#                     "img": "https://imgs.search.brave.com/JjwiCYT9sT0GetVYNSfpZkN1ecDE0iGSBn7KENE2S3I/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYTU3YWZmYmEy/ZmZlMmY0YTFhN2Nk/YWZkNGY5NGQxMjhj/OGM2MmRlMTUxYWUz/NjI3YjU1MjRlYTc0/NzBhNTNmNy93d3cu/dm9kYWZvbmUuY29t/Lw"
#                 },
#                 "language": "unk",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "vodafone.com",
#                     "hostname": "www.vodafone.com",
#                     "favicon": "https://imgs.search.brave.com/JjwiCYT9sT0GetVYNSfpZkN1ecDE0iGSBn7KENE2S3I/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvYTU3YWZmYmEy/ZmZlMmY0YTFhN2Nk/YWZkNGY5NGQxMjhj/OGM2MmRlMTUxYWUz/NjI3YjU1MjRlYTc0/NzBhNTNmNy93d3cu/dm9kYWZvbmUuY29t/Lw",
#                     "path": "› content  › dam  › vodcom  › sustainability  › pdfs  › Vodafone_Statement_on_Cobalt_Sourcing_2017.pdf"
#                 },
#                 "thumbnail": null,
#                 "age": null
#             },
#             {
#                 "title": "Author and anti-slavery activist to speak on cobalt mining in the ...",
#                 "url": "https://news.cornell.edu/stories/2023/11/author-and-anti-slavery-activist-speak-cobalt-mining-congo",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "Siddharth Kara, award-winning author and anti-slavery activist, will discuss the immense toll <strong>cobalt</strong> <strong>mining</strong> has had on the people and environment of the Democratic Republic of the Congo at noon on Friday, November 10.",
#                 "page_age": null,
#                 "profile": {
#                     "name": "Cornell",
#                     "url": "https://news.cornell.edu/stories/2023/11/author-and-anti-slavery-activist-speak-cobalt-mining-congo",
#                     "long_name": "news.cornell.edu",
#                     "img": "https://imgs.search.brave.com/w9wAbyDSgJnZV_xO33EdCVJShesxH146ptavho1uPQ4/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMGVhZjIyMmJh/MmNlOWYyZTY4MmNl/NzI5ZDliMGFlNjg1/NWI1YjViZTlhMjE1/ZWYwNzA3MDFjZGM2/NDExZmM5MS9uZXdz/LmNvcm5lbGwuZWR1/Lw"
#                 },
#                 "language": "en",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "news.cornell.edu",
#                     "hostname": "news.cornell.edu",
#                     "favicon": "https://imgs.search.brave.com/w9wAbyDSgJnZV_xO33EdCVJShesxH146ptavho1uPQ4/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMGVhZjIyMmJh/MmNlOWYyZTY4MmNl/NzI5ZDliMGFlNjg1/NWI1YjViZTlhMjE1/ZWYwNzA3MDFjZGM2/NDExZmM5MS9uZXdz/LmNvcm5lbGwuZWR1/Lw",
#                     "path": "› stories  › 2023  › 11  › author-and-anti-slavery-activist-speak-cobalt-mining-congo"
#                 },
#                 "thumbnail": {
#                     "src": "https://imgs.search.brave.com/0MiQLUSQLAEl67RqIBUAJMhEchHPwJk7x_I0jEAVkV0/rs:fit:200:200:1/g:ce/aHR0cHM6Ly9uZXdz/LmNvcm5lbGwuZWR1/L3NpdGVzL2RlZmF1/bHQvZmlsZXMvc3R5/bGVzL3N0b3J5X3Ro/dW1ibmFpbF9sZy9w/dWJsaWMvMl8xLnBu/Zz9pdG9rPTU0TUlP/ZjZq",
#                     "original": "https://news.cornell.edu/sites/default/files/styles/story_thumbnail_lg/public/2_1.png?itok=54MIOf6j",
#                     "logo": false
#                 },
#                 "age": null
#             },
#             {
#                 "title": "Idaho cobalt mine - Wikipedia",
#                 "url": "https://en.wikipedia.org/wiki/Idaho_cobalt_mine",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "Idaho <strong>Cobalt</strong> Operations (ICO) is a <strong>cobalt</strong> <strong>mine</strong> located in Lemhi County, Idaho in the United States near the town of Salmon. The <strong>mine</strong> has reserves amounting to 3.8 million tonnes of ore grading 0.5% <strong>cobalt</strong>. <strong>The</strong> <strong>mine</strong> will also produce copper and gold. The project is located directly adjacent ...",
#                 "page_age": "2023-03-30T21:08:07",
#                 "profile": {
#                     "name": "Wikipedia",
#                     "url": "https://en.wikipedia.org/wiki/Idaho_cobalt_mine",
#                     "long_name": "en.wikipedia.org",
#                     "img": "https://imgs.search.brave.com/0kxnVOiqv-faZvOJc7zpym4Zin1CTs1f1svfNZSzmfU/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw"
#                 },
#                 "language": "en",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "https",
#                     "netloc": "en.wikipedia.org",
#                     "hostname": "en.wikipedia.org",
#                     "favicon": "https://imgs.search.brave.com/0kxnVOiqv-faZvOJc7zpym4Zin1CTs1f1svfNZSzmfU/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvNjQwNGZhZWY0/ZTQ1YWUzYzQ3MDUw/MmMzMGY3NTQ0ZjNj/NDUwMDk5ZTI3MWRk/NWYyNTM4N2UwOTE0/NTI3ZDQzNy9lbi53/aWtpcGVkaWEub3Jn/Lw",
#                     "path": "› wiki  › Idaho_cobalt_mine"
#                 },
#                 "thumbnail": null,
#                 "age": "March 30, 2023"
#             },
#             {
#                 "title": "Cobalt Mining in the Democratic Republic of the Congo",
#                 "url": "http://large.stanford.edu/courses/2021/ph240/larios1/",
#                 "is_source_local": false,
#                 "is_source_both": false,
#                 "description": "The most common process includes hydrometallurgical refining to directly produce either a <strong>cobalt</strong> cathode or hydroxide. [4] In other processes, the <strong>mined</strong> ore is agitated to separate the minerals in a process called separation flotation. The concentrates can be sold as is or split into two other ...",
#                 "page_age": "2021-11-12T00:00:00",
#                 "profile": {
#                     "name": "Stanford",
#                     "url": "http://large.stanford.edu/courses/2021/ph240/larios1/",
#                     "long_name": "large.stanford.edu",
#                     "img": "https://imgs.search.brave.com/AjP3k8TEIjLDEhc25FJNgPUgHke_I_ryYUpV2nkmRxc/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMTE1ZjM1MzRm/N2E3YzAzZjJiZTU1/MWIwZTA4ZWRhMDRh/MDA1ZTc2MjBkYjQ2/OGMyNGMyZDExMjU5/YjM0ZWE5Yy9sYXJn/ZS5zdGFuZm9yZC5l/ZHUv"
#                 },
#                 "language": "en",
#                 "family_friendly": true,
#                 "type": "search_result",
#                 "subtype": "generic",
#                 "meta_url": {
#                     "scheme": "http",
#                     "netloc": "large.stanford.edu",
#                     "hostname": "large.stanford.edu",
#                     "favicon": "https://imgs.search.brave.com/AjP3k8TEIjLDEhc25FJNgPUgHke_I_ryYUpV2nkmRxc/rs:fit:32:32:1/g:ce/aHR0cDovL2Zhdmlj/b25zLnNlYXJjaC5i/cmF2ZS5jb20vaWNv/bnMvMTE1ZjM1MzRm/N2E3YzAzZjJiZTU1/MWIwZTA4ZWRhMDRh/MDA1ZTc2MjBkYjQ2/OGMyNGMyZDExMjU5/YjM0ZWE5Yy9sYXJn/ZS5zdGFuZm9yZC5l/ZHUv",
#                     "path": "› courses  › 2021  › ph240  › larios1"
#                 },
#                 "thumbnail": null,
#                 "age": "November 12, 2021"
#             }
#         ],
#         "family_friendly": true
#     }
# }
